# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd
import numpy as np
# reading the CSV file
csvFile = pd.read_csv('40reglast.csv')
# displaying the contents of the CSV file
df = pd.DataFrame(csvFile)
#df.drop(columns=['D', 'H'])
#data_top = df.head() 
# print(df)
df.loc[df['H'] !='insn per cycle','G'] = '0'
df
# Out:
#               A              B   C                         D         E      F  \
# 0      0.040133          90928 NaN             branch-misses   3709143   9.22
# 1      0.040133           4294 NaN          iTLB-load-misses   7699945  19.14
# 2      0.040133          31667 NaN          dTLB-load-misses  11694713  29.08
# 3      0.040133          38320 NaN         dTLB-store-misses  15691700  39.02
# 4      0.040133         179279 NaN     L1-icache-load-misses  15999483  39.79
# 5      0.040133       11915663 NaN     L1-dcache-load-misses  16004476  39.81
# 6      0.040133         600874 NaN  l2_rqsts.all_demand_miss  16000354  39.80
# 7      0.040133         282686 NaN           LLC-load-misses  15999476  39.80
# 8      0.040133          53174 NaN          LLC-store-misses  15997705  39.80
# 9      0.040133      141616543 NaN                    cycles  16000277  39.81
# 10     0.040133      261418197 NaN              instructions  12530533  31.18
# ...

# %%
li=[]
for i in df['B']:
    li.append(i)
print(len(li))
arr=np.array(li)
arr.resize(597,15)
arr.shape
arr
# Out:
# 8955
# array([['90928', '4294', '31667', ..., '2811670', '154324',
#         '<not counted>'],
#        ['185972', '1250', '46389', ..., '2385865', '319842', '287268'],
#        ['308589', '3266', '146886', ..., '3518488', '896539', '368066'],
#        ...,
#        ['<not counted>', '22990', '23263', ..., '4362759', '685766',
#         '13946'],
#        ['1130291', '7243', '56573', ..., '3930308', '526984', '54474'],
#        ['32244', '2934', '16249', ..., '5199804', '130227', '34232']],
#       dtype='<U13')

# %%
df_new = pd.DataFrame(arr, columns =['branch-misses','iTLB-load-misses','dTLB-load-misses','dTLB-store-misses','L1-icache-load-misses','L1-dcache-load-misses','l2_rqsts.all_demand_miss','LLC-load-misses','LLC-store-misses','cycles','instructions','L1-dcache-loads1','L1-dcache-load-misses1','LLC-loads1','LLC-load-misses1'])
df_new = df_new.replace('<not counted>','0')  
del df_new['L1-dcache-load-misses']
del df_new['LLC-load-misses1']
del df_new['L1-dcache-loads1']
del df_new['LLC-loads1']
del df_new['cycles']
del df_new['instructions']

# %%
li2=[]
for i in df['G']:
    li2.append(i)
li3=[]
for i in range(10,len(li2),15):
    li3.append(li2[i])
df_new['CPI']=li3
df_new
# Out:
#     branch-misses iTLB-load-misses dTLB-load-misses dTLB-store-misses  \
# 0           90928             4294            31667             38320
# 1          185972             1250            46389              8295
# 2          308589             3266           146886              3922
# 3          320195             1098            34169              4714
# 4          217128             1319            80523              6485
# 5          476108             7635            79051              1066
# 6          404809             1232           111799              5497
# 7          277577             2246            63070              3217
# 8          391651             1021            74015              5278
# 9          595929             1232           109469              3015
# 10         260651             1438            70836              4687
# 11         330906             1445           105072              7928
# ...

# %%
print(df_new['CPI'].astype(float).mean())
for i in list(df_new):
    df_new[i]=df_new[i].replace('0',df_new[i].astype(float).mode())
df.['CPI'].replace('1.42','1')
df_new
# Out:
#   File "<ipython-input-43-2d7c096a927a>", line 4
#     df.['CPI'].replace('1.42','1')
#        ^
# SyntaxError: invalid syntax

# %%
# Save the dataframe to a CSV file
df_new.to_csv('datasetQ2_final.csv',index=False)
